# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreshthSaxena/Algorithmic-Trading/blob/master/yolo3_keras%20(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_path = 'gdrive/My Drive/YOLO/keras-yolo3'  
#import shutil
#shutil.move("keras-yolo3/rac_train.py", "gdrive/My Drive/YOLO/keras-yolo3")

# %%
cd gdrive/My Drive/YOLO/keras-yolo3
# Out:
# /content/gdrive/My Drive/YOLO/keras-yolo3

# %%
# !rm yolo.py

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3eeea909-fb99-4e31-afeb-3caa15bc7c76" name="files[]" multiple disabled />
#      <output id="result-3eeea909-fb99-4e31-afeb-3caa15bc7c76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving yolo.py to yolo.py
# ...

# %%
# !python rac_train.py

# %%
# !python train_bottleneck.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-05-15 18:09:22.610117: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-05-15 18:09:22.610424: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x23c91e0 executing computations on platform Host. Devices:
# 2019-05-15 18:09:22.610465: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-15 18:09:22.828588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !unzip bottlenecks.npz
# Out:
# Archive:  bottlenecks.npz
#  extracting: bot0.npy
#  extracting: bot1.npy
#  extracting: bot2.npy

# %%
# !python yolo_video.py --help
# Out:
# Using TensorFlow backend.
# usage: yolo_video.py [-h] [--model MODEL] [--anchors ANCHORS]
#                      [--classes CLASSES] [--gpu_num GPU_NUM] [--image]
#                      [--input [INPUT]] [--output [OUTPUT]]
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --model MODEL      path to model weight file, default
#                      logs/000/trained_weights_final.h5
#   --anchors ANCHORS  path to anchor definitions, default
#                      model_data/yolo_anchors.txt
#   --classes CLASSES  path to class definitions, default
#                      model_data/rac_classes.txt
#   --gpu_num GPU_NUM  Number of GPU to use, default 1
#   --image            Image detection mode, will ignore all positional
#                      arguments
#   --input [INPUT]    Video input path
#   --output [OUTPUT]  [Optional] Video output path

# %%
# !python yolo_video.py --image
# Out:
# Using TensorFlow backend.
# Image detection mode
#  Ignoring remaining command line arguments: ./path2your_video,
# 2019-05-15 19:59:34.892167: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-05-15 19:59:34.892401: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x34671e0 executing computations on platform Host. Devices:
# 2019-05-15 19:59:34.892433: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-15 19:59:35.099973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-15 19:59:35.100733: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3466dc0 executing computations on platform CUDA. Devices:
# ...

# %%
#!git clone https://github.com/qqwweee/keras-yolo3
#!zip -r /model.zip -i /model_data
#from google.colab import files
#files.download("model.zip")
# Out:
# fatal: destination path 'keras-yolo3' already exists and is not an empty directory.

# %%
from IPython.display import Image
Image('l1.jpg', width=416, height=416)

# %%
Image('l2.jpg', width=416, height=416)

# %%
Image('l3.jpg', width=416, height=416)

# %%
Image('l4.jpg', width=416, height=416)

# %%
Image('l5.jpg', width=416, height=416)

# %%
Image('last.jpg', width=416, height=416)
